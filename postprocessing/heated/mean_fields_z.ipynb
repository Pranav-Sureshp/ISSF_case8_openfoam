# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
simulation_file = './Tmean_umean_z_x-p3.csv'
paper_data =  '../postprocessing_Mistrangelo/Fig9.csv'

# 1. Read the CSV file (assumes 1st line is the header)
df = pd.read_csv(simulation_file); paper = pd.read_csv(paper_data) ;

# 2. Define the columns you want to plot
# Replace these with your actual column names from the CSV header
x_col = 'Points_2'
y_col = 'T'

# 3. Create the plot with big font sizes
plt.figure(figsize=(10, 6))

# Use the plot function from matplotlib
plt.plot(df[x_col], df[y_col]-273,'r-*',markevery=10,label=f'simulation', linewidth=2)
plt.plot(paper.iloc[:,0], paper.iloc[:,1],'bs-', label=f'Mistrangelo et al.(2026)', linewidth=2)


# 4. Set labels and title with big fontsize
plt.xlabel(r'z', fontsize=18) ; plt.ylabel(r'$\overline{T} (^\circ C) $', fontsize=18)

# 5. Add a legend with big fontsize
plt.legend(fontsize=16, loc='best')

# 6. Increase tick label sizes
plt.xticks(fontsize=14) ; plt.yticks(fontsize=14)

plt.grid(True)
plt.tight_layout()
plt.savefig('./Tmean_z_x-p3.png', dpi=300,bbox_inches='tight')

# %%
paper_data =  '../postprocessing_Mistrangelo/Fig12.csv'
# 1. Read the CSV file (assumes 1st line is the header)
df = pd.read_csv(simulation_file); paper = pd.read_csv(paper_data) ;

# 2. Define the columns you want to plot
# Replace these with your actual column names from the CSV header
x_col = 'Points_2'
y_col = 'UMean_0'

# 3. Create the plot with big font sizes
plt.figure(figsize=(10, 6))

# Use the plot function from matplotlib
plt.plot(df[x_col], df[y_col],'r-*',markevery=10,label=f'simulation', linewidth=2)
plt.plot(paper.iloc[:,0], paper.iloc[:,1],'bs-', label=f'Mistrangelo et al.(2026)', linewidth=2)


# 4. Set labels and title with big fontsize
plt.xlabel(r'z', fontsize=18) ; plt.ylabel(r'$\overline{U}$ (m/s)', fontsize=18)

# 5. Add a legend with big fontsize
plt.legend(fontsize=16, loc='best')

# 6. Increase tick label sizes
plt.xticks(fontsize=14) ; plt.yticks(fontsize=14)

plt.grid(True)
plt.tight_layout()
plt.savefig('./Umean_z_x-p3.png', dpi=300,bbox_inches='tight')

# %%
simulation_file = './Fig15-phimean-x.csv'
paper_data =  '../postprocessing_Mistrangelo/Fig15.csv'

# 1. Read the CSV file (assumes 1st line is the header)
df = pd.read_csv(simulation_file); paper = pd.read_csv(paper_data) ;
df.fillna(0.0)

# 2. Define the columns you want to plot
# Replace these with your actual column names from the CSV header
x_col = 'Points_0'
y_col = 'PotEMean'

# 3. Create the plot with big font sizes
plt.figure(figsize=(10, 6))

# Use the plot function from matplotlib
plt.plot(df[x_col], df[y_col]*1000000,'r-*',markevery=10,label=f'simulation', linewidth=2)
plt.plot(paper.iloc[:,0], paper.iloc[:,1],'bs-', label=f'Mistrangelo et al.(2026)', linewidth=2)


# 4. Set labels and title with big fontsize
plt.xlabel(r'x', fontsize=18) ; plt.ylabel(r'$\overline{\phi} (\mu V) $', fontsize=18)

# 5. Add a legend with big fontsize
plt.legend(fontsize=16, loc='best')

# 6. Increase tick label sizes
plt.xticks(fontsize=14) ; plt.yticks(fontsize=14)

plt.grid(True)
plt.tight_layout()
plt.savefig('./Phi_x.png', dpi=300,bbox_inches='tight')

# %% [markdown]
# ## Tav

# %%
simulation_file = '../report_postprocess/lineZ_y0_x1_Tav_Uav_code.csv'

# 1. Read the CSV file (assumes 1st line is the header)
df = pd.read_csv(simulation_file);
df.fillna(0.0)

# 2. Define the columns you want to plot
# Replace these with your actual column names from the CSV header
x_col = 'Points_2' ; y_col = 'TMean'

# 3. Create the plot with big font sizes
plt.figure(figsize=(10, 6))

# Use the plot function from matplotlib
plt.plot(df[x_col], df[y_col]-273,'r-*',markevery=10,label=f'simulation', linewidth=2)

# 4. Set labels and title with big fontsize
plt.xlabel(r'x', fontsize=18) ; plt.ylabel(r'$\overline{T} (^\circ C) $', fontsize=18)

# 5. Add a legend with big fontsize
plt.legend(fontsize=16, loc='best')

# 6. Increase tick label sizes
plt.xticks(fontsize=14) ; plt.yticks(fontsize=14)

plt.grid(True) ; 
plt.tight_layout()
plt.savefig('./Tav_x1_y0_z.png', dpi=300,bbox_inches='tight')

# %%
# 2. Define the columns you want to plot
# Replace these with your actual column names from the CSV header
x_col = 'Points_2' ; y_col = 'UMean_0'

# 3. Create the plot with big font sizes
plt.figure(figsize=(10, 6))

# Use the plot function from matplotlib
plt.plot(df[x_col], df[y_col],'r-*',markevery=10,label=f'simulation', linewidth=2)

# 4. Set labels and title with big fontsize
plt.xlabel(r'x', fontsize=18) ; plt.ylabel(r'$\overline{U} (m/s) $', fontsize=18)

# 5. Add a legend with big fontsize
plt.legend(fontsize=16, loc='best')

# 6. Increase tick label sizes
plt.xticks(fontsize=14) ; plt.yticks(fontsize=14)

plt.grid(True) ; plt.tight_layout()
plt.savefig('./Uav_x1_y0_z.png', dpi=300,bbox_inches='tight')
